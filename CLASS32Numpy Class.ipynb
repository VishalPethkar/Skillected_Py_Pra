# %%
#-- 01 NumPy --

# %%
NumPy (Numerical Python) is the foundation of all data science in Python. 
It provides fast, memory-efficient arrays and mathematical operations. 
Pandas, Matplotlib, and Scikit-learn all build on NumPy.

# %%
import numpy as np
marks = np.array([12,45,11,98,10,15,88,43])
marks + 5
# Out:
# array([ 17,  50,  16, 103,  15,  20,  93,  48])
