# %%
#-- Example -- present else returns the second argument

a1 = {
    'name':'vish',
    'age':22,
    'email':'vish@gmail.com'
}

# %%
print(a1)
# Out:
# {'name': 'vish', 'age': 22, 'email': 'vish@gmail.com'}

# %%
a1.get('name')
# Out:
# 'vish'

# %%
a1['name']
# Out:
# 'vish'

# %%
a1.clear()
a1
# Out:
# {}

# %%
a1.keys()
# Out:
# dict_keys([])

# %%
a1.values()
# Out:
# dict_values([])

# %%
a1.items()
# Out:
# dict_items([])

# %%
a2 = {
    "name": "vish",
    "marks": 71,
    "class": "12th",
    "percentage": 77
}

# %%
#Change Key Name Slightly
a2 = dict(name='vish', marks=71, class_name='12th', percentage=77)

# %%
a3 = dict([(1,1),(1,1),(1,1)])
print(a3)
# Out:
# {1: 1}

# %%
a4 = dict([(1,1),(2,2),(3,3)])
print(a4)
# Out:
# {1: 1, 2: 2, 3: 3}

# %%
#different wey to creating a dict--

#1.
a1 = {
    'name':'vish',
    'age':21
}


#2.
a2 = dict([(1,1),(2,2),(3,3)])


#3.
d = dict(name = 'vish',age = 21)

# %%
#-- Example -- 

a1 = {
    'one':1,
    'two':2,
    'three':3,
    'four':4
}

a1
# Out:
# {'one': 1, 'two': 2, 'three': 3, 'four': 4}

# %%
print(a1,id(a1))
# Out:
# {'one': 1, 'two': 2, 'three': 3, 'four': 4} 2654604040000

# %%
a2 = a1.copy()
print(a2,id(a2))
# Out:
# {'one': 1, 'two': 2, 'three': 3, 'four': 4} 2654604026048

# %%
a2 = a1.copy()
print(id(a2))
# Out:
# 2654604133376

# %%
a2.pop('one')
print(a2)
# Out:
# {'two': 2, 'three': 3, 'four': 4}

# %%
a2.popitem()
print(a2)
# Out:
# {'two': 2, 'three': 3}

# %%
a3 = {'eleven':11,'twelve':12}
a3
# Out:
# {'eleven': 11, 'twelve': 12}

# %%
a2.update(a3)
a2
# Out:
# {'two': 2, 'three': 3, 'eleven': 11, 'twelve': 12}

# %%
a2.setdefault('thirty')
a2.get('thirty','not eresent')
print(a2)
# Out:
# {'two': 2, 'three': 3, 'eleven': 11, 'twelve': 12, 'thirty': None}

# %%
a2.setdefault('forty',40)
# Out:
# 40

# %%
a2 = dict.fromkeys(['thirty'], 30)
print(a2)
# Out:
# {'thirty': 30}

# %%
a3 = a2.fromkeys(('company','fruit','color'),'orange')
print(a3)
# Out:
# {'company': 'orange', 'fruit': 'orange', 'color': 'orange'}

# %%
a3 = a4.fromkeys(('company','fruit','color'),('org','apple'))
print(a3)
# Out:
# {'company': ('org', 'apple'), 'fruit': ('org', 'apple'), 'color': ('org', 'apple')}
